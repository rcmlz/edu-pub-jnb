# %% [markdown]
# # Titel der Analyse

# %% [markdown]
# Untertitel
#
# Ihr Name

# %% [markdown]
# ## Forschungsfrage

# %% [markdown]
# ## Daten einlesen

# %%
import pandas as pd

# %%
df = pd.read_csv('pfad/zur/csv/datei.csv', sep=";")
df

# %% [markdown]
# ## Daten vorverarbeiten

# %% [markdown]
# ## Daten analysieren

# %% [markdown]
# ## Daten visualisieren

# %% [markdown]
# # while_tutorial.ipynb
#
# **Thema:** Die `while`-Schleife in Python — kurzes interaktives Tutorial
#
# **Dauer:** 30 Minuten
#
# ---
#
# **Ziele:**
#
# - Markdown, Code und Slides in einem Jupyter Notebook nutzen
# - Grundlagen der `while`-Schleife verstehen und anwenden
# - Eine kurze Präsentation (Slides) aus dem Notebook erzeugen

# %% [markdown]
# ## Inhaltsverzeichnis
#
# 1. Einführung und Motivation
# 2. Einfache `while`-Schleifen
# 3. `break`- und Abbruchbedingungen
# 4. Zähler und Schleifenbeispiele
# 5. Bilder (extern + lokal)
# 6. Präsentation (RISE / Slideshow)

# %% [markdown]
# ### 1) Einführung
#
# > Eine `while`-Schleife wiederholt einen Block so lange, wie eine Bedingung `True` ist.
#
# **Syntax (kurz):**
#
# `while <bedingung>:`
#
# Schleifen sind nützlich, wenn die Anzahl der Wiederholungen nicht vorher bekannt ist.

# %%
# Einfaches Beispiel: Zähle von 1 bis 5 mit einer while-Schleife
n = 1
while n <= 5:
    print('Durchlauf', n)
    n += 1

# Das ergibt 5 Zeilen. Diesen Code kannst du mit Run → Run All Cells ausführen.

# %% [markdown]
# ### 2) Abbruch mit `break`
#
# Manchmal will man die Schleife vorzeitig beenden. Dazu verwendet man `break`.

# %%
# Beispiel: Suche nach der ersten Zahl, die durch 7 teilbar ist
x = 1
while True:  # Endlosschleife mit Abbruch
    if x % 7 == 0:
        print('Erste durch 7 teilbare Zahl:', x)
        break
    x += 1

# Wichtig: Endlosschleifen immer so gestalten, dass sie sicher abbrechen.

# %% [markdown]
# ### 3) Eingaben und Schleifen
#
# Hier zeigen wir, wie man `input()` verwenden kann — der Zellenaufruf ruft **nicht** `input()` automatisch beim `Run All` auf,
# sondern ist als Funktion vorbereitet, damit `Run All Cells` nicht blockiert. Du kannst die Funktion einzeln ausführen, um interaktiv zu testen.
#
# ```python
# # Beispiel (nicht automatisch aufgerufen):
# # def interactive_counter():
# #     limit = int(input('Gib eine obere Grenze ein: '))
# #     i = 1
# #     while i <= limit:
# #         print(i)
# #         i += 1
# ```

# %%
def interactive_counter_simulated(limit=3):
    '''Simuliertes Beispiel, damit Run All Cells nicht blockiert.'''
    i = 1
    while i <= limit:
        print(i)
        i += 1

# Funktion aufrufen mit einer Beispiel-Grenze
interactive_counter_simulated(3)

# %% [markdown]
# ### 4) Aufgaben / kleine Übungen
#
# 1. Schreibe eine `while`-Schleife, die die Quadratzahlen (1, 4, 9, ...) bis zu 100 ausgibt.
# 2. Schreibe eine `while`-Schleife, die die Benutzereingabe (wiederholte Strings) liest, bis der Benutzer `stop` eingibt. (Testweise als Funktion implementiert.)

# %%
# Aufgabe 1: Quadratzahlen bis 100
n = 1
while n*n <= 100:
    print(n*n)
    n += 1

# Aufgabe 2: simulierte stop-Schleife (nicht interaktiv, damit Run All Cells durchläuft)
def simulated_input_loop(sequence):
    idx = 0
    while idx < len(sequence):
        s = sequence[idx]
        print('eingabe:', s)
        if s.lower() == 'stop':
            print('Stop erkannt — Schleife beendet')
            break
        idx += 1

simulated_input_loop(['hallo', 'test', 'stop', 'noch'])

# %% [markdown]
# ### 5) Bilder einbinden
#
# - **Externes Bild:** das Bild wird über eine URL eingebunden.
# - **Lokales Bild:** das Notebook erstellt ein lokales Bild (`bild_local.png`) automatisch, sodass `Run All Cells` fehlerfrei läuft.
#
# Beispiel-Markdown (externes Bild):
#
# ![Externes Bild](https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/web/pandas/static/img/pandas.svg)
#
# Beispiel-Markdown (lokales Bild):
#
# ![Lokales Bild](bild_local.png)

# %%
# Zeige die Bilder auch programmatisch (IPython.display)
from IPython.display import Image, display

print('Externes Bild (wird aus dem Netz geladen):')
display(Image(url='https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/web/pandas/static/img/pandas.svg', width=200))

print('\nLokales Bild (aus dem Notebook-Verzeichnis):')
display(Image(filename='bild_local.png', width=200))

# %% [markdown]
# ### 6) Präsentation / Slides
#
# Dieses Notebook ist für die Verwendung mit **RISE** oder dem internen Slideshow-Modus vorbereitet.
# **Wie:** View → Cell Toolbar → Slideshow → für jede Zelle den Typ (Slide, Sub-slide, Fragment, Skip, Notes) setzen.
#
# **Tipp:** Teste die Präsentation mit:
#
# - Run → Run All Cells
# - Dann RISE (falls installiert) oder View → Cell Toolbar → Slideshow und `Enter` im Präsentationsmodus
#
# ---
#
# **Sprechernotiz (Notes):** Verwende die Notes-Zellen, um Stichworte für deinen Vortrag zu schreiben.

# %% [markdown]
# ---
#
# ### Abgabe-Checkliste
#
# - [x] Alle Code-Zellen ausführen: Run → Run All Cells (keine interaktiven `input()`-Aufrufe, es gibt simulierte Beispiele)
# - [x] Markdown-Formatierung verwendet
# - [x] Externes und lokales Bild eingebunden
# - [x] Slideshow-Metadaten gesetzt (Slide/Sub-slide/Fragment)
#
# **Dateien:**
#
# - while_tutorial.ipynb
# - bild_local.png
#
# Viel Erfolg! 🍀

# %% [markdown]
# # Datenanalyse mit Pandas
#
# https://pandas.pydata.org/docs/getting_started/intro_tutorials

# %%
import pandas as pd

# %% [markdown]
# Pandas ist eine Python-Bibliothek, mit der sehr leicht Daten analysiert und dargestellt werden können. Zusammen mit Jupyter ist das quasi wie Word, Excel und Powerpoint zusammen und ist besonders geeignet für Data Scientists und alle anderen Menschen, die empirische (quantitative) Analysen auf grossen Datenmengen reproduzierbar und zuverlässig durchführen müssen/wollen/können.

# %% [markdown]
# Tipp: öffne das Inhaltsverzeichnis auf der linken Seitenleiste - Easy Navigation!

# %% [markdown]
# ### Die Daily-Routine des Data-Scientists
# - Daten einlesen
# - Daten validieren und bereinigen
# - Berechnungen durchführen
#   - deskriptive Statistik (min, max, mean, median, ...)
#   - induktive Statistik (Hypothesen und Modelle)
#   - erkundende Statistik (explorative Datenanalyse)
# - Ergebnisse visualisieren
# - Ergebnisse präsentieren

# %% [markdown]
# ```mermaid
# stateDiagram-v2
#     [*] --> Forschungsfrage
#     Forschungsfrage --> Datenbeschaffung
#     Datenbeschaffung --> Test
#     Datenbeschaffung --> Produktiv
#     Test --> Vorverarbeitung
#     Produktiv --> Vorverarbeitung
#     Vorverarbeitung --> Analyse
#     Vorverarbeitung --> Test
#     Analyse --> Visualisierung
#     Analyse --> Vorverarbeitung
#     Visualisierung --> Ausarbeitung
#     Visualisierung --> Analyse
#     Ausarbeitung --> Präsentation
#     Ausarbeitung --> Visualisierung
#     Präsentation --> Ausarbeitung
#     Präsentation --> [*]
# ```

# %% [markdown]
# Ob medizinische, biolologische, soziologische, psychologische oder technische Fragestellungen quantitativ (empirisch) untersucht werden sollen - das Vorgehen ist immer ähnlich.
#
# i.d.R. sehr zeitaufwändig: die Rohdaten besorgen, verstehen, validieren und bereinigen.
#
# CSV-Files (Comma Separated Values) sind der einfachste Weg, (grosse) Datenmengen sicher auszutauschen.

# %% [markdown]
# ![01_table_dataframe.svg](img/01_table_dataframe.svg)

# %% [markdown]
# Wie in jeder Tabellenkalkulation gibt es in Pandas Spalten und Zeilen.

# %% [markdown]
# ---

# %%
#
# Platzhalter für optionale Anbindung an Ollama
#

# %% [markdown]
# ---

# %% [markdown]
# # Titanic – Wer hatte eine Überlebenschance?
#
# Untersuche den bekannten Titanic-Datensatz mit Pandas.
#
# Wähle mindestens drei Fragestellungen, die sich mit den vorhandenen Daten beantworten lassen.

# %% [markdown]
# Für jede Fragestellung:
#
# - Formuliere die Frage.
# - Wähle die benötigten Daten aus.
# - Führe eine geeignete Auswertung mit Pandas durch.
# - Stelle das Ergebnis als Tabelle oder Diagramm dar.
# - Formuliere eine verständliche Antwort.
# - Beurteile, ob die Daten tatsächlich ausreichen, um deine Frage zu beantworten.

# %% [markdown]
# ## Daten Einlesen

# %%
import pandas as pd

# %% [markdown]
# Öffne die Datei [titanic.csv](data/titanic.csv) aus dem Ordner `analysen/Titanic/data` mit einem Rechtsklick (Open with -> Editor).
#
# Q: Wie lautet das Trennzeichen (Delimiter)?

# %% [markdown]
# ### aus einer lokalen Datei

# %%
titanic = pd.read_csv("data/titanic.csv")

# %% [markdown]
# ### oder direkt aus dem Netz ...

# %%
titanic = pd.read_csv("https://link.melzian.ch/titanic")

# %% [markdown]
# Dies ist ein für diese Präsentation verkürzter Link auf
# https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/titanic.csv

# %% [markdown]
# Weitere Testdaten für Pandas findest du hier: https://github.com/pandas-dev/pandas/tree/main/doc/data
#
# Wenn möglich alle Rohdaten lokal speichern. Warum? Wegen der Reproduzierbarkeit!

# %% [markdown]
# ## Rohdaten anzeigen und verstehen

# %%
titanic.info()

# %%
titanic.describe()

# %%
titanic.head()

# %%
titanic.tail()

# %% [markdown]
# Q: Wie viele Personen sind im Datensatz enthalten?

# %%
# Wenn das Notebook mit Ollama verbudnen ist, dann können wir einfach fragen, wie es geht.
# Wir geben eine Beschreibung des DataFrames mit - woher soll das LLM auch wissen, wie unsere Spalten heissen, richitg?

chat(""" Gegeben ist folgender Pandas DataFrame

<class 'pandas.core.frame.DataFrame'>
RangeIndex: 891 entries, 0 to 890
Data columns (total 12 columns):
 #   Column       Non-Null Count  Dtype  
---  ------       --------------  -----  
 0   PassengerId  891 non-null    int64  
 1   Survived     891 non-null    int64  
 2   Pclass       891 non-null    int64  
 3   Name         891 non-null    object 
 4   Sex          891 non-null    object 
 5   Age          714 non-null    float64
 6   SibSp        891 non-null    int64  
 7   Parch        891 non-null    int64  
 8   Ticket       891 non-null    object 
 9   Fare         891 non-null    float64
 10  Cabin        204 non-null    object 
 11  Embarked     889 non-null    object 
dtypes: float64(2), int64(5), object(5)

Wie berechne ich die Anzahl der Personen, die im DataFrame enthalten sind?
""")

# %% [markdown]
# Q: Wie viele Merkmale gibt es?

# %% [markdown]
# Q: Welche Informationen enthält der Datensatz? Erkläre die Bedeutung der Spalten:
#
# - PassengerId
# - Survived
# - Pclass
# - Name
# - Sex
# - Age
# - SibSp
# - Parch
# - Ticket
# - Fare
# - Cabin
# - Embarked

# %% [markdown]
# Q: Welche Spalten enthalten Zahlen?

# %% [markdown]
# Q: Welche enthalten Text?

# %% [markdown]
# Q: Welche Spalten enthalten fehlende Werte?

# %% [markdown]
# Q: Lass dir die ersten zehn Datensätze anzeigen.

# %% [markdown]
# ## und dann Berechnungen anstellen

# %% [markdown]
# Q: Wie viele Passagiere haben überlebt und wie viele sind gestorben?

# %% [markdown]
# Q: Berechne den Anteil der Überlebenden in Prozent.

# %% [markdown]
# Q: Wie hoch war das durchschnittliche Alter?

# %% [markdown]
# Q: Wie alt war die jüngste Person?

# %% [markdown]
# Q: Wie alt war die älteste Person?

# %% [markdown]
# Q: Wie viel kostete eine Fahrkarte durchschnittlich?

# %% [markdown]
# Q: Bestimme den günstigsten und teuersten Fahrpreis.

# %% [markdown]
# Hier wird groupby() oder pivot_table() interessant.

# %% [markdown]
# Q: Wie viele Passagiere gab es in jeder Passagierklasse?

# %% [markdown]
# Q: Wie viele Männer und Frauen gab es in den einzelnen Passagierklassen?

# %% [markdown]
# Q: Wie unterscheidet sich die Überlebensrate zwischen Frauen und Männern?

# %% [markdown]
# Q: Hat die Passagierklasse einen Einfluss auf die Überlebenschance?

# %% [markdown]
# Q: Welche Kombination aus Geschlecht und Passagierklasse hatte die höchste Überlebensrate?

# %% [markdown]
# ## Wie mit fehlenden Daten umgehen?

# %% [markdown]
# Q: In welchen Spalten fehlen Daten?

# %% [markdown]
# Q: Wie viele Werte fehlen jeweils?

# %% [markdown]
# Q: Wie gross ist der Anteil der fehlenden Altersangaben?

# %% [markdown]
# Q: Was könnte man mit fehlenden Altersangaben machen? Diskutiere verschiedene Möglichkeiten:
#
# - Datensatz unverändert lassen
# - Zeilen entfernen
# - fehlende Werte durch den Mittelwert ersetzen
# - fehlende Werte durch den Median ersetzen
#
# Welche Variante würdest du wählen? Begründe deine Entscheidung.

# %% [markdown]
# ## Beispielhafte Forschungsfragen

# %% [markdown]
# ### Frauen und Kinder zuerst?
#
# Welche Personengruppen hatten die grösste Überlebenschance?
#
# Untersuche den Zusammenhang zwischen:
#
# - Geschlecht
# - Alter
# - Passagierklasse
# - Überleben
#
# Formuliere am Ende eine begründete Aussage.

# %% [markdown]
# ### War die 1. Klasse wirklich sicherer?
#
# Hatten Passagiere der 1. Klasse tatsächlich bessere Überlebenschancen als Passagiere der 3. Klasse?
#
# Belege deine Antwort mit mindestens zwei Auswertungen oder Diagrammen.

# %% [markdown]
# ### Teure Tickets = höhere Überlebenschance?
#
# Gibt es einen Zusammenhang zwischen Fahrpreis und Überlebenschance?
#
# Untersuche:
#
# - Fare
# - Survived
#
# Erstelle eine geeignete Visualisierung und interpretiere das Ergebnis.

# %% [markdown]
# ### Familie an Bord
#
# SibSp beschreibt Geschwister/Ehepartner an Bord, Parch Eltern/Kinder.
#
# Hatten Personen mit Familienmitgliedern an Bord eine höhere Überlebenschance?
#
# Erzeuge dazu beispielsweise eine neue Variable:
#
# `Familienmitglieder = SibSp + Parch`
#
# Untersuche anschliessend den Zusammenhang mit `Survived`.

# %% [markdown]
# ### Weitere Fragestellungen

# %% [markdown]
# Q: Wie gross ist die Überlebensrate abhängig von Geschlecht UND Passagierklasse?
#
# Erstelle eine Kreuztabelle.

# %% [markdown]
# Q: Welche Altersgruppe hatte innerhalb jeder Passagierklasse die höchste Überlebensrate?

# %% [markdown]
# Q: Gibt es einen Zusammenhang zwischen Fahrpreis und Passagierklasse? Untersuche den durchschnittlichen Fahrpreis der drei Klassen.

# %% [markdown]
# Q: Welche Kombination aus Geschlecht, Alter und Passagierklasse war besonders gefährdet?

# %% [markdown]
# ## aussagekräftig Plotten
#
# Ein Bild sagt ja bekanntlich mehr als tausend Worte

# %% [markdown]
# Pandas-DataFrames können Daten direkt als Grafik ausgeben - man spricht von `plotten`, weshalb der Befehl folgerichtig [.plot()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html) heisst.

# %% [markdown]
# Q: Erstelle ein Diagramm, das zeigt, wie viele Personen überlebt haben bzw. gestorben sind.

# %% [markdown]
# Q: Erstelle ein Diagramm, das die Überlebensrate von Frauen und Männern vergleicht.

# %% [markdown]
# Q: Erstelle ein Diagramm, das die Überlebensrate der drei Passagierklassen vergleicht.

# %% [markdown]
# Q: Wie verändert sich die Überlebensrate mit dem Alter?
#
# Teile die Passagiere beispielsweise in diese Altersgruppen:
#
# - 0–9
# - 10–19
# - 20–29
# - 30–39
# - 40–49
# - 50–59
# - 60+

# %% [markdown]
# Beispiel: Manchmal müssen wir vor dem Plotten noch etwas berechnen, hier bspw. das Durchschnittsalter aller Passagiere pro Klasse.

# %%
img = titanic.groupby('Pclass')['Age'].mean()\
             .plot.bar(title="Durchschnittsalter pro Passagierklasse")

# %% [markdown]
# Q: Ein Bild in einer Datei speichern

# %% [markdown]
# So können die Grafiken auch leicht in PowerPoint, [Prezi](https://prezi.com) u.A. Präsentationsprogrammen weiterverwendet werden.

# %%
img.get_figure().savefig('img/barplot.svg')

# %% [markdown]
# Balkendiagramm? Wie langweilig! Geht das besser? Klar, mit [Boxplots](https://de.wikipedia.org/wiki/Box-Plot)

# %%
img = titanic.boxplot(column="Age", by="Pclass", ylabel="Passagierklasse", showmeans=True, vert=False)

# %%
img.get_figure().savefig('img/boxplot.svg')

# %% [markdown]
# Interpretation: Junge Menschen reisen wohl hauptsächlich 3. Klasse ...

# %% [markdown]
# ## La fin
# ![Pandas_Logo](img/Pandas_logo.svg)

# %% [markdown]
# Abschluss-Slide
#
# - Fragen?
# - Anregungen?
# - Meinungen
#
# aus dem Pubklikum abholen.

# %% [markdown]
# ## Anhang - mit diversen Tipps und Tricks

# %% [markdown]
# Code-Zellen, die mit `%%bash` beginnen, führen einen Befehl im Terminal aus.

# %%
# %%bash
# curl --output img/Pandas_logo.svg https://upload.wikimedia.org/wikipedia/commons/e/ed/Pandas_logo.svg

# %%
# %%bash
# tree

# %% [markdown]
# Du kannst die verfügbaren Dateien links in der Seitenleiste sehen oder dir auch per Kommandozeilenbefehl `tree` übersichtlich anzeigen lassen:

# %% [markdown]
# Vielleicht möchtest du die Rohdaten einer Analyse herunterladen und zusammen mit dem Notebook speichern? Sicher ist sicher? Das kannst du automatisch und reproduzierbar direkt in Jupyter tun, bspw. mit dem Befehl `curl`:

# %%
# %%bash
# curl --output data/iris.csv https://raw.githubusercontent.com/pandas-dev/pandas/refs/heads/main/doc/data/iris.data

# %% [markdown]
# Alternativ kannst du das natürlich auch alles manuell im Browser erledigen und dann die Datei von deinem Rechner nach Jupyter hochladen.

# %% [markdown]
# Den Projektordner als Ganzes kannst du in eine zip-Datei verpacken und anschliessend auf deinen Rechner herunterladen. Das ist insbesondere nützlich, um deine Abgabe in Teams vorzubereiten oder wenn du deine Arbeit auf einen anderen Rechner übertragen willst.

# %%
# %%bash
# zip --exclude '*.ipynb_checkpoints*' --recurse-paths Pandas-Tutorial.zip .

# %% [markdown]
# `Pandas-Tutorial.zip` ist ein von dir vorgegebener Dateiname für das zu erstellende zip-Archiv. Mit `.` setzt du den aktuellen Ordner als Startpunkt. Mit `--recurse-paths` sorgst du dafür, dass alle Dateien und Unterordner im Archiv erfasst werden. Der Parameter `--exclude '*.ipynb_checkpoints*'` sorgt dafür, dass Sicherheitskopien, welche verwendet werden, wenn du `Edit -> Undo/Redo` verwendest, nicht mit im zip-Archiv landen.

# %% [markdown]
# Wenn du dieses Notizbuch in eine Reveal.js-Präsentation exportierst (`File -> Save and Export As -> Reveal.js Slides`), dann achte darauf, auch den Ordner mit deinen Bildern in den gleichen Ordner wie die .html-Datei auf deinem Rechner zu kopieren. Eine zip-Datei zum Herunterladen mit Namen `bilder.zip` aller Dateien im Ordner `img` erstellst du so:

# %%
# %%bash
# zip --exclude '*.ipynb_checkpoints*' --recurse-paths bilder.zip img/

# %% [markdown]
# Falls du neben einer Präsentation auch noch eine pdf-Datei aus diesem Notebook erstellen willst und dafür Grafiken im `.png`-Format anstelle von bspw. `.svg` benötigst, so kannst du mit dem Befehl `magick input.file output.file` leicht Bilder konvertieren, etwa so:

# %%
# %%bash
# # entweder convert oder magick
# magick img/01_table_dataframe.svg img/01_table_dataframe.png

# %% [markdown]
# oder du lässt die Konvertierung aller `svg`-Bilder automatisch durchführen.

# %%
# %%bash
# # file to convert - ohne .ipynb
# FILE=Pandas-Tutorial
# # ipynb to LaTeX
# jupyter nbconvert $FILE.ipynb --to latex &> /dev/null
# # add svg package to first line of LaTeX file
# sed -i '1 s/.*/&\\usepackage{svg}/' $FILE.tex
# # LaTeX to pdf
# xelatex --shell-escape $FILE.tex -quiet -interaction='nonstopmode' &> /dev/null
# # clean up
# rm -rf svg-inkscape $FILE\_files
# rm $FILE.aux $FILE.log $FILE.out $FILE.tex

# %% [markdown]
# Vorher musst du dafür die JupyterHub-VM ggf. durch Eingabe [des hier gezeigten](https://publish.obsidian.md/mer/Unterlagen/Jupyer-Quick-Start#VM+reparieren+oder+aktualisieren) Kommandos aktualisieren. Passe dann die Zeile `FILE=...` entsprechend dem Dateinamen deines Notebooks an und führe erst dann diese Codezelle aus:

# %% [markdown]
# Wenn du keine `.svg` Dateien in deinem Notebook verwendet hast oder diese schon manuell nach `.png` konvertiert und eingebunden hast, dann kannst du ein .pdf-File auch einfach via `File -> Save and Export As -> PDF` erstellen.

# %%
# %%bash
# tree

# %% [markdown]
# In der JupyterHub-VM funktioniert der Button für den Präsentations-Modus nicht. Du musst die Ansicht bei Bedarf direkt aufrufen.
#
# `http://127.0.0.1:8000/user/USER/rise/PATH/TO/NOTEBOOK`
#
# Wenn du beispielsweise mit dem Nutzer `demo` eingeloggt bis und dieses Notebook (`edu-public-jupyter-notebooks/analysen/Pandas-Tutorial/Pandas-Tutorial.ipynb`) live präsentieren willst:
#
# http://127.0.0.1:8000/user/demo/rise/edu-public-jupyter-notebooks/analysen/Pandas-Tutorial/Pandas-Tutorial.ipynb

# %% [markdown]
# https://mermaid.live
# <pre>
# ```mermaid
# flowchart TD
#     A[Christmas] -->|Get money| B(Go shopping)
#     B --> C{Let me think}
#     C -->|One| D[Laptop]
#     C -->|Two| E[iPhone]
#     C -->|Three| F[fa:fa-car Car]
# ```
# </pre>

# %% [markdown]
# ```mermaid
# flowchart TD
#     A[Christmas] -->|Get money| B(Go shopping)
#     B --> C{Let me think}
#     C -->|One| D[Laptop]
#     C -->|Two| E[iPhone]
#     C -->|Three| F[fa:fa-car Car]
# ```

# %% [markdown]
# ![01_table_dataframe.svg](img/mermaid-screenshot.png)

# %% [markdown]
# Du kannst auch https://mermaid.live Grafiken einbinden.

# %% [markdown]
# <pre>
# $$v = \frac{s}{t}$$
# </pre>
#
# oder
#
# <pre>
# $F = m \cdot \overrightarrow{a}$
# </pre>

# %% [markdown]
# Bitten Sie ein LLM doch mal um eine mathematische Formel in [LaTeX](https://www.overleaf.com/learn/latex/List_of_Greek_letters_and_math_symbols). Das sollte irgendwas in die Richtung geben:

# %% [markdown]
# $$v = \frac{s}{t}$$
#
# $F = m \cdot \overrightarrow{a}$
#
# <p style="font-size:4em">$$a = \sum_{i=1}^{10} 2^{i}$$</p>

# %% [markdown]
# style="font-size:4em" a = \sum_{i=1}^{10} 2^{i}
